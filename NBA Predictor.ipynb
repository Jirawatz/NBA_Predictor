# %% [markdown]
# # NBA Predictor
# ### Motivation
# Our motivation for the project is to try and see if we can predict which current college basketball players will have successful NBA players. Even today, certain college players seem like they will be stars in the league and they end up being busts, we aim to shed some light as to whose skills will properly translate at the next level.
#
# ### Summary of Data Processing Pipeline

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

def get_nba_player_html(year):
    """ Web scrapping https://www.basketball-reference.com/leagues/NBA_2021_totals.html
        to retrieve NBA player college statistic
        
        Args:
            year (int) : Represent year in yyyy format (e.g. 2021)
        
        Return:
            df_nba_player (DataFrame) : Represent the dataframe that contain NBA player
    """
    nba_player = f'https://www.basketball-reference.com/leagues/NBA_{year}_totals.html'
    html_player = requests.get(nba_player)
    status = html_player.status_code
    
    # If page load correctly
    if status == 200:
        return html_player.text
    
def extract_nba_player(html_player):
    """ Extract the NBA player from the crawled webpage in order to retrieve stat
    
        Args:
            html_player (String) : Represent the crawled league webpage
            
        Return:
            df_player (DataFrame) : Represent list of player and corresponding stat URL
    """
    base_url = 'https://www.basketball-reference.com'
    soup = BeautifulSoup(html_player)
    df_player = pd.DataFrame()
    
    # Find all player with stat URL
    for player in soup.find_all('td', {'data-stat': 'player'}):
        link = player.find_all('a')[0]
        
        # Construct Dict that contain Player Name and URL to player stat
        dict_player = {'player_name' : player.text,
                      'url' : base_url + link.attrs['href']}
        
        df_player = df_player.append(dict_player, ignore_index=True)
        
    
    # Drop any duplicate and retain the first entries
    df_player.drop_duplicates(subset='player_name', keep='first', inplace=True)
        
    return df_player



def get_nba_collegestat(player_url):
    """ Web Scrapping https://www.basketball-reference.com/players and retrive player's
        college statistic
        
        Args:
            player_url (String) : Represent URL that contain player stat
            
        Return:
            html_stat (String) : Represent the stat for all NBA player in HTML
    """
    html_stat = requests.get(player_url)
    status = html_stat.status_code
    
    # If page load correctly
    if status == 200:
        return html_stat.text
    
def extract_nba_collegestat(html_stat):
    """ Extract college stat from NBA player
    
        Args:
            html_stat (String) : Represent the crawled player stat webpage
            
        Return:
            dict_stat (Dictionary) : Represent the player college stat
    """
    soup = BeautifulSoup(html_stat)
    
    # Clean up hidden scripts
    stat_wcomment = soup.find_all('div', {'id':'all_all_college_stats'})
    str_stat = str(stat_wcomment[0]).replace('<!--','').replace('-->','')
    
    soup = BeautifulSoup(str_stat)
    stat_body = soup.find('tbody')
    
    # Initalize Dict
    dict_stat = {}

    # Add year
    for year in stat_body.find_all('th'):
        # Get Year and Value
        key = year.get('data-stat')
        value = year.text
        
        if key not in dict_stat.keys():
            dict_stat[key] = [value]
        else:
            dict_stat[key] = dict_stat[key] + [value]
    
    
    # Add Stat Information
    for stat in stat_body.find_all('td'):
        # Get Metric and Value
        key = stat.get('data-stat')
        value = stat.text
        
        if key not in dict_stat.keys():
            dict_stat[key] = [value]
        else:
            dict_stat[key] = dict_stat[key] + [value]
           
    return dict_stat
    
def build_nba_college(df_player):
    """ Build the NBA college Data given list of player and URL
    
        Args:
            df_player (DataFrame) : Represent list of Player and corresponding stat URL
            
        Return:
            df_nba_collegestat (DataFrame) : Represent the NBA Player college stat
    """
    df_nba_collegestat = pd.DataFrame()
    
    for idx, row in df_player.iterrows():
        player = row['player_name']
        url = row['url']
        
        print(url)
        
        player_stat_url = get_nba_collegestat(url)
        dict_player_stat = extract_nba_collegestat(player_stat_url)
        
        df_player_temp = pd.DataFrame(dict_player_stat)
        df_player_temp['player_name'] = player
        
        df_nba_collegestat = df_nba_collegestat.append(df_player_temp)
        
    return df_nba_collegestat

# %%
html_player = get_nba_player_html(2021)
df_player = extract_nba_player(html_player)

# %%
df_player['url'][0]
build_nba_college(df_player)
# Out:
# 0 player_name                                     Precious Achiuwa
# url            https://www.basketball-reference.com/players/a...
# Name: 0, dtype: object
# 1 player_name                                         Jaylen Adams
# url            https://www.basketball-reference.com/players/a...
# Name: 1, dtype: object
# 2 player_name                                         Steven Adams
# url            https://www.basketball-reference.com/players/a...
# Name: 2, dtype: object
# 3 player_name                                          Bam Adebayo
# url            https://www.basketball-reference.com/players/a...
# Name: 3, dtype: object
# 4 player_name                                    LaMarcus Aldridge
# url            https://www.basketball-reference.com/players/a...
# Name: 4, dtype: object
# 7 player_name                                    Ty-Shon Alexander
# url            https://www.basketball-reference.com/players/a...
# Name: 7, dtype: object
# 8 player_name                             Nickeil Alexander-Walker
# url            https://www.basketball-reference.com/players/a...
# Name: 8, dtype: object
# 9 player_name                                        Grayson Allen
# url            https://www.basketball-reference.com/players/a...
# Name: 9, dtype: object
# 10 player_name                                        Jarrett Allen
# url            https://www.basketball-reference.com/players/a...
# Name: 10, dtype: object
# 13 player_name                                      Al-Farouq Aminu
# url            https://www.basketball-reference.com/players/a...
# Name: 13, dtype: object
# 16 player_name                                        Kyle Anderson
# url            https://www.basketball-reference.com/players/a...
# Name: 16, dtype: object
# 17 player_name                                Giannis Antetokounmpo
# url            https://www.basketball-reference.com/players/a...
# Name: 17, dtype: object
# 18 player_name                                 Kostas Antetokounmpo
# url            https://www.basketball-reference.com/players/a...
# Name: 18, dtype: object
# 19 player_name                               Thanasis Antetokounmpo
# url            https://www.basketball-reference.com/players/a...
# Name: 19, dtype: object
# 20 player_name                                      Carmelo Anthony
# url            https://www.basketball-reference.com/players/a...
# Name: 20, dtype: object
# 21 player_name                                         Cole Anthony
# url            https://www.basketball-reference.com/players/a...
# Name: 21, dtype: object
# 22 player_name                                           OG Anunoby
# url            https://www.basketball-reference.com/players/a...
# Name: 22, dtype: object
# 23 player_name                                     Ryan Arcidiacono
# url            https://www.basketball-reference.com/players/a...
# Name: 23, dtype: object
# 24 player_name                                         Trevor Ariza
# url            https://www.basketball-reference.com/players/a...
# Name: 24, dtype: object
# 25 player_name                                        D.J. Augustin
# url            https://www.basketball-reference.com/players/a...
# Name: 25, dtype: object
# 28 player_name                                          Deni Avdija
# url            https://www.basketball-reference.com/players/a...
# Name: 28, dtype: object
# 29 player_name                                        Deandre Ayton
# url            https://www.basketball-reference.com/players/a...
# Name: 29, dtype: object
# 30 player_name                                       Udoka Azubuike
# url            https://www.basketball-reference.com/players/a...
# Name: 30, dtype: object
# 31 player_name                                         Dwayne Bacon
# url            https://www.basketball-reference.com/players/b...
# Name: 31, dtype: object
# 32 player_name                                    Marvin Bagley III
# url            https://www.basketball-reference.com/players/b...
# Name: 32, dtype: object
# 33 player_name                                          LaMelo Ball
# url            https://www.basketball-reference.com/players/b...
# Name: 33, dtype: object
# 34 player_name                                           Lonzo Ball
# url            https://www.basketball-reference.com/players/b...
# Name: 34, dtype: object
# 35 player_name                                             Mo Bamba
# url            https://www.basketball-reference.com/players/b...
# Name: 35, dtype: object
# 36 player_name                                         Desmond Bane
# url            https://www.basketball-reference.com/players/b...
# Name: 36, dtype: object
# 37 player_name                                      Harrison Barnes
# url            https://www.basketball-reference.com/players/b...
# Name: 37, dtype: object
# 38 player_name                                           RJ Barrett
# url            https://www.basketball-reference.com/players/b...
# Name: 38, dtype: object
# 39 player_name                                          Will Barton
# url            https://www.basketball-reference.com/players/b...
# Name: 39, dtype: object
# 40 player_name                                     Keita Bates-Diop
# url            https://www.basketball-reference.com/players/b...
# Name: 40, dtype: object
# 41 player_name                                        Nicolas Batum
# url            https://www.basketball-reference.com/players/b...
# Name: 41, dtype: object
# 42 player_name                                          Aron Baynes
# url            https://www.basketball-reference.com/players/b...
# Name: 42, dtype: object
# 43 player_name                                        Kent Bazemore
# url            https://www.basketball-reference.com/players/b...
# Name: 43, dtype: object
# 44 player_name                                        Darius Bazley
# url            https://www.basketball-reference.com/players/b...
# Name: 44, dtype: object
# 45 player_name                                         Bradley Beal
# url            https://www.basketball-reference.com/players/b...
# Name: 45, dtype: object
# 46 player_name                                        Malik Beasley
# url            https://www.basketball-reference.com/players/b...
# Name: 46, dtype: object
# 47 player_name                                          Jordan Bell
# url            https://www.basketball-reference.com/players/b...
# Name: 47, dtype: object
# 50 player_name                                      DeAndre' Bembry
# url            https://www.basketball-reference.com/players/b...
# Name: 50, dtype: object
# 51 player_name                                        Dāvis Bertāns
# url            https://www.basketball-reference.com/players/b...
# Name: 51, dtype: object
# 52 player_name                                     Patrick Beverley
# url            https://www.basketball-reference.com/players/b...
# Name: 52, dtype: object
# 53 player_name                                           Saddiq Bey
# url            https://www.basketball-reference.com/players/b...
# Name: 53, dtype: object
# 54 player_name                                            Tyler Bey
# url            https://www.basketball-reference.com/players/b...
# Name: 54, dtype: object
# 55 player_name                                           Khem Birch
# url            https://www.basketball-reference.com/players/b...
# Name: 55, dtype: object
# 58 player_name                                         Goga Bitadze
# url            https://www.basketball-reference.com/players/b...
# Name: 58, dtype: object
# 59 player_name                                      Bismack Biyombo
# url            https://www.basketball-reference.com/players/b...
# Name: 59, dtype: object
# 60 player_name                                      Nemanja Bjelica
# url            https://www.basketball-reference.com/players/b...
# Name: 60, dtype: object
# 63 player_name                                         Eric Bledsoe
# url            https://www.basketball-reference.com/players/b...
# Name: 63, dtype: object
# 64 player_name                                       Keljin Blevins
# url            https://www.basketball-reference.com/players/b...
# Name: 64, dtype: object
# 65 player_name                                    Bogdan Bogdanović
# url            https://www.basketball-reference.com/players/b...
# Name: 65, dtype: object
# 66 player_name                                     Bojan Bogdanović
# url            https://www.basketball-reference.com/players/b...
# Name: 66, dtype: object
# 67 player_name                                              Bol Bol
# url            https://www.basketball-reference.com/players/b...
# Name: 67, dtype: object
# 68 player_name                                       Marques Bolden
# url            https://www.basketball-reference.com/players/b...
# Name: 68, dtype: object
# 69 player_name                                          Jordan Bone
# url            https://www.basketball-reference.com/players/b...
# Name: 69, dtype: object
# 70 player_name                                          Isaac Bonga
# url            https://www.basketball-reference.com/players/b...
# Name: 70, dtype: object
# 71 player_name                                         Devin Booker
# url            https://www.basketball-reference.com/players/b...
# Name: 71, dtype: object
# 72 player_name                                        Chris Boucher
# url            https://www.basketball-reference.com/players/b...
# Name: 72, dtype: object
# 73 player_name                                          Brian Bowen
# url            https://www.basketball-reference.com/players/b...
# Name: 73, dtype: object
# 74 player_name                                        Avery Bradley
# url            https://www.basketball-reference.com/players/b...
# Name: 74, dtype: object
# 77 player_name                                         Tony Bradley
# url            https://www.basketball-reference.com/players/b...
# Name: 77, dtype: object
# 80 player_name                                     Jarrell Brantley
# url            https://www.basketball-reference.com/players/b...
# Name: 80, dtype: object
# 81 player_name                                     Ignas Brazdeikis
# url            https://www.basketball-reference.com/players/b...
# Name: 81, dtype: object
# 85 player_name                                        Mikal Bridges
# url            https://www.basketball-reference.com/players/b...
# Name: 85, dtype: object
# 86 player_name                                        Miles Bridges
# url            https://www.basketball-reference.com/players/b...
# Name: 86, dtype: object
# 87 player_name                                         Amida Brimah
# url            https://www.basketball-reference.com/players/b...
# Name: 87, dtype: object
# 88 player_name                                       Oshae Brissett
# url            https://www.basketball-reference.com/players/b...
# Name: 88, dtype: object
# 89 player_name                                      Malcolm Brogdon
# url            https://www.basketball-reference.com/players/b...
# Name: 89, dtype: object
# 90 player_name                                        Armoni Brooks
# url            https://www.basketball-reference.com/players/b...
# Name: 90, dtype: object
# 91 player_name                                        Dillon Brooks
# url            https://www.basketball-reference.com/players/b...
# Name: 91, dtype: object
# 92 player_name                                          Bruce Brown
# url            https://www.basketball-reference.com/players/b...
# Name: 92, dtype: object
# 93 player_name                                    Charlie Brown Jr.
# url            https://www.basketball-reference.com/players/b...
# Name: 93, dtype: object
# 94 player_name                                         Jaylen Brown
# url            https://www.basketball-reference.com/players/b...
# Name: 94, dtype: object
# 95 player_name                                          Moses Brown
# url            https://www.basketball-reference.com/players/b...
# Name: 95, dtype: object
# 96 player_name                                       Sterling Brown
# url            https://www.basketball-reference.com/players/b...
# Name: 96, dtype: object
# 97 player_name                                       Troy Brown Jr.
# url            https://www.basketball-reference.com/players/b...
# Name: 97, dtype: object
# 100 player_name                                        Jalen Brunson
# url            https://www.basketball-reference.com/players/b...
# Name: 100, dtype: object
# 101 player_name                                        Elijah Bryant
# url            https://www.basketball-reference.com/players/b...
# Name: 101, dtype: object
# 102 player_name                                        Thomas Bryant
# url            https://www.basketball-reference.com/players/b...
# Name: 102, dtype: object
# 103 player_name                                       Reggie Bullock
# url            https://www.basketball-reference.com/players/b...
# Name: 103, dtype: object
# 104 player_name                                           Trey Burke
# url            https://www.basketball-reference.com/players/b...
# Name: 104, dtype: object
# 105 player_name                                           Alec Burks
# url            https://www.basketball-reference.com/players/b...
# Name: 105, dtype: object
# 106 player_name                                         Jimmy Butler
# url            https://www.basketball-reference.com/players/b...
# Name: 106, dtype: object
# 107 player_name                                        Bruno Caboclo
# url            https://www.basketball-reference.com/players/c...
# Name: 107, dtype: object
# 108 player_name                                       Devontae Cacok
# url            https://www.basketball-reference.com/players/c...
# Name: 108, dtype: object
# 109 player_name                             Kentavious Caldwell-Pope
# url            https://www.basketball-reference.com/players/c...
# Name: 109, dtype: object
# 110 player_name                                     Facundo Campazzo
# url            https://www.basketball-reference.com/players/c...
# Name: 110, dtype: object
# 111 player_name                                        Vlatko Čančar
# url            https://www.basketball-reference.com/players/c...
# Name: 111, dtype: object
# 112 player_name                                        Devin Cannady
# url            https://www.basketball-reference.com/players/c...
# Name: 112, dtype: object
# 113 player_name                                         Clint Capela
# url            https://www.basketball-reference.com/players/c...
# Name: 113, dtype: object
# 114 player_name                                     Vernon Carey Jr.
# url            https://www.basketball-reference.com/players/c...
# Name: 114, dtype: object
# 115 player_name                                         Jevon Carter
# url            https://www.basketball-reference.com/players/c...
# Name: 115, dtype: object
# 116 player_name                                   Wendell Carter Jr.
# url            https://www.basketball-reference.com/players/c...
# Name: 116, dtype: object
# 119 player_name                              Michael Carter-Williams
# url            https://www.basketball-reference.com/players/c...
# Name: 119, dtype: object
# 120 player_name                                          Alex Caruso
# url            https://www.basketball-reference.com/players/c...
# Name: 120, dtype: object
# 121 player_name                                  Willie Cauley-Stein
# url            https://www.basketball-reference.com/players/c...
# Name: 121, dtype: object
# 122 player_name                                        Chris Chiozza
# url            https://www.basketball-reference.com/players/c...
# Name: 122, dtype: object
# 123 player_name                                      Marquese Chriss
# url            https://www.basketball-reference.com/players/c...
# Name: 123, dtype: object
# 124 player_name                                           Gary Clark
# url            https://www.basketball-reference.com/players/c...
# Name: 124, dtype: object
# 128 player_name                                       Brandon Clarke
# url            https://www.basketball-reference.com/players/c...
# Name: 128, dtype: object
# 129 player_name                                      Jordan Clarkson
# url            https://www.basketball-reference.com/players/c...
# Name: 129, dtype: object
# 130 player_name                                          Nic Claxton
# url            https://www.basketball-reference.com/players/c...
# Name: 130, dtype: object
# 131 player_name                                          Amir Coffey
# url            https://www.basketball-reference.com/players/c...
# Name: 131, dtype: object
# 132 player_name                                         John Collins
# url            https://www.basketball-reference.com/players/c...
# Name: 132, dtype: object
# 133 player_name                                          Mike Conley
# url            https://www.basketball-reference.com/players/c...
# Name: 133, dtype: object
# 134 player_name                                      Pat Connaughton
# url            https://www.basketball-reference.com/players/c...
# Name: 134, dtype: object
# 135 player_name                                           Quinn Cook
# url            https://www.basketball-reference.com/players/c...
# Name: 135, dtype: object
# 138 player_name                                           Tyler Cook
# url            https://www.basketball-reference.com/players/c...
# Name: 138, dtype: object
# 141 player_name                                     DeMarcus Cousins
# url            https://www.basketball-reference.com/players/c...
# Name: 141, dtype: object
# 144 player_name                                     Robert Covington
# url            https://www.basketball-reference.com/players/c...
# Name: 144, dtype: object
# 145 player_name                                         Torrey Craig
# url            https://www.basketball-reference.com/players/c...
# Name: 145, dtype: object
# 148 player_name                                          Jae Crowder
# url            https://www.basketball-reference.com/players/c...
# Name: 148, dtype: object
# 149 player_name                                       Jarrett Culver
# url            https://www.basketball-reference.com/players/c...
# Name: 149, dtype: object
# 150 player_name                                           Seth Curry
# url            https://www.basketball-reference.com/players/c...
# Name: 150, dtype: object
# 151 player_name                                        Stephen Curry
# url            https://www.basketball-reference.com/players/c...
# Name: 151, dtype: object
# 152 player_name                                         Nate Darling
# url            https://www.basketball-reference.com/players/d...
# Name: 152, dtype: object
# 153 player_name                                        Anthony Davis
# url            https://www.basketball-reference.com/players/d...
# Name: 153, dtype: object
# 154 player_name                                             Ed Davis
# url            https://www.basketball-reference.com/players/d...
# Name: 154, dtype: object
# 155 player_name                                        Terence Davis
# url            https://www.basketball-reference.com/players/d...
# Name: 155, dtype: object
# 158 player_name                                         Gabriel Deck
# url            https://www.basketball-reference.com/players/d...
# Name: 158, dtype: object
# 159 player_name                                       Dewayne Dedmon
# url            https://www.basketball-reference.com/players/d...
# Name: 159, dtype: object
# 160 player_name                                  Matthew Dellavedova
# url            https://www.basketball-reference.com/players/d...
# Name: 160, dtype: object
# 161 player_name                                        DeMar DeRozan
# url            https://www.basketball-reference.com/players/d...
# Name: 161, dtype: object
# 162 player_name                                       Mamadi Diakite
# url            https://www.basketball-reference.com/players/d...
# Name: 162, dtype: object
# 163 player_name                                       Hamidou Diallo
# url            https://www.basketball-reference.com/players/d...
# Name: 163, dtype: object
# 166 player_name                                         Gorgui Dieng
# url            https://www.basketball-reference.com/players/d...
# Name: 166, dtype: object
# 169 player_name                                    Spencer Dinwiddie
# url            https://www.basketball-reference.com/players/d...
# Name: 169, dtype: object
# 170 player_name                                     Donte DiVincenzo
# url            https://www.basketball-reference.com/players/d...
# Name: 170, dtype: object
# 171 player_name                                          Luka Dončić
# url            https://www.basketball-reference.com/players/d...
# Name: 171, dtype: object
# 172 player_name                                        Luguentz Dort
# url            https://www.basketball-reference.com/players/d...
# Name: 172, dtype: object
# 173 player_name                                       Damyean Dotson
# url            https://www.basketball-reference.com/players/d...
# Name: 173, dtype: object
# 174 player_name                                         Devon Dotson
# url            https://www.basketball-reference.com/players/d...
# Name: 174, dtype: object
# 175 player_name                                      Sekou Doumbouya
# url            https://www.basketball-reference.com/players/d...
# Name: 175, dtype: object
# 176 player_name                                            PJ Dozier
# url            https://www.basketball-reference.com/players/d...
# Name: 176, dtype: object
# 177 player_name                                         Goran Dragić
# url            https://www.basketball-reference.com/players/d...
# Name: 177, dtype: object
# 178 player_name                                       Andre Drummond
# url            https://www.basketball-reference.com/players/d...
# Name: 178, dtype: object
# 181 player_name                                         Jared Dudley
# url            https://www.basketball-reference.com/players/d...
# Name: 181, dtype: object
# 182 player_name                                            Kris Dunn
# url            https://www.basketball-reference.com/players/d...
# Name: 182, dtype: object
# 183 player_name                                         Kevin Durant
# url            https://www.basketball-reference.com/players/d...
# Name: 183, dtype: object
# 184 player_name                                      Anthony Edwards
# url            https://www.basketball-reference.com/players/e...
# Name: 184, dtype: object
# 185 player_name                                       Carsen Edwards
# url            https://www.basketball-reference.com/players/e...
# Name: 185, dtype: object
# 186 player_name                                            CJ Elleby
# url            https://www.basketball-reference.com/players/e...
# Name: 186, dtype: object
# 187 player_name                                       Henry Ellenson
# url            https://www.basketball-reference.com/players/e...
# Name: 187, dtype: object
# 188 player_name                                      Wayne Ellington
# url            https://www.basketball-reference.com/players/e...
# Name: 188, dtype: object
# 189 player_name                                          Joel Embiid
# url            https://www.basketball-reference.com/players/e...
# Name: 189, dtype: object
# 190 player_name                                      James Ennis III
# url            https://www.basketball-reference.com/players/e...
# Name: 190, dtype: object
# 191 player_name                                         Drew Eubanks
# url            https://www.basketball-reference.com/players/e...
# Name: 191, dtype: object
# 192 player_name                                           Dante Exum
# url            https://www.basketball-reference.com/players/e...
# Name: 192, dtype: object
# 193 player_name                                           Tacko Fall
# url            https://www.basketball-reference.com/players/f...
# Name: 193, dtype: object
# 194 player_name                                       Derrick Favors
# url            https://www.basketball-reference.com/players/f...
# Name: 194, dtype: object
# 195 player_name                                    Cristiano Felício
# url            https://www.basketball-reference.com/players/f...
# Name: 195, dtype: object
# 196 player_name                                    Terrance Ferguson
# url            https://www.basketball-reference.com/players/f...
# Name: 196, dtype: object
# 197 player_name                                       Bruno Fernando
# url            https://www.basketball-reference.com/players/f...
# Name: 197, dtype: object
# 198 player_name                                         Yogi Ferrell
# url            https://www.basketball-reference.com/players/f...
# Name: 198, dtype: object
# 201 player_name                                  Dorian Finney-Smith
# url            https://www.basketball-reference.com/players/f...
# Name: 201, dtype: object
# 202 player_name                                          Malik Fitts
# url            https://www.basketball-reference.com/players/f...
# Name: 202, dtype: object
# 203 player_name                                        Malachi Flynn
# url            https://www.basketball-reference.com/players/f...
# Name: 203, dtype: object
# 204 player_name                                          Bryn Forbes
# url            https://www.basketball-reference.com/players/f...
# Name: 204, dtype: object
# 205 player_name                                        Trent Forrest
# url            https://www.basketball-reference.com/players/f...
# Name: 205, dtype: object
# 206 player_name                                        Evan Fournier
# url            https://www.basketball-reference.com/players/f...
# Name: 206, dtype: object
# 209 player_name                                         De'Aaron Fox
# url            https://www.basketball-reference.com/players/f...
# Name: 209, dtype: object
# 210 player_name                                        Robert Franks
# url            https://www.basketball-reference.com/players/f...
# Name: 210, dtype: object
# 211 player_name                                          Tim Frazier
# url            https://www.basketball-reference.com/players/f...
# Name: 211, dtype: object
# 212 player_name                                         Enes Freedom
# url            https://www.basketball-reference.com/players/k...
# Name: 212, dtype: object
# 213 player_name                                       Markelle Fultz
# url            https://www.basketball-reference.com/players/f...
# Name: 213, dtype: object
# 214 player_name                                       Wenyen Gabriel
# url            https://www.basketball-reference.com/players/g...
# Name: 214, dtype: object
# 215 player_name                                       Daniel Gafford
# url            https://www.basketball-reference.com/players/g...
# Name: 215, dtype: object
# 218 player_name                                     Danilo Gallinari
# url            https://www.basketball-reference.com/players/g...
# Name: 218, dtype: object
# 219 player_name                                    Langston Galloway
# url            https://www.basketball-reference.com/players/g...
# Name: 219, dtype: object
# 220 player_name                                       Darius Garland
# url            https://www.basketball-reference.com/players/g...
# Name: 220, dtype: object
# 221 player_name                                           Marc Gasol
# url            https://www.basketball-reference.com/players/g...
# Name: 221, dtype: object
# 222 player_name                                             Rudy Gay
# url            https://www.basketball-reference.com/players/g...
# Name: 222, dtype: object
# 223 player_name                                          Paul George
# url            https://www.basketball-reference.com/players/g...
# Name: 223, dtype: object
# 224 player_name                                           Taj Gibson
# url            https://www.basketball-reference.com/players/g...
# Name: 224, dtype: object
# 225 player_name                                          Harry Giles
# url            https://www.basketball-reference.com/players/g...
# Name: 225, dtype: object
# 226 player_name                              Shai Gilgeous-Alexander
# url            https://www.basketball-reference.com/players/g...
# Name: 226, dtype: object
# 227 player_name                                         Anthony Gill
# url            https://www.basketball-reference.com/players/g...
# Name: 227, dtype: object
# 228 player_name                                    Freddie Gillespie
# url            https://www.basketball-reference.com/players/g...
# Name: 228, dtype: object
# 229 player_name                                          Rudy Gobert
# url            https://www.basketball-reference.com/players/g...
# Name: 229, dtype: object
# 230 player_name                                      Brandon Goodwin
# url            https://www.basketball-reference.com/players/g...
# Name: 230, dtype: object
# 231 player_name                                         Aaron Gordon
# url            https://www.basketball-reference.com/players/g...
# Name: 231, dtype: object
# 234 player_name                                          Eric Gordon
# url            https://www.basketball-reference.com/players/g...
# Name: 234, dtype: object
# 235 player_name                                      Devonte' Graham
# url            https://www.basketball-reference.com/players/g...
# Name: 235, dtype: object
# 236 player_name                                         Jerami Grant
# url            https://www.basketball-reference.com/players/g...
# Name: 236, dtype: object
# 237 player_name                                          Danny Green
# url            https://www.basketball-reference.com/players/g...
# Name: 237, dtype: object
# 238 player_name                                       Draymond Green
# url            https://www.basketball-reference.com/players/g...
# Name: 238, dtype: object
# 239 player_name                                       JaMychal Green
# url            https://www.basketball-reference.com/players/g...
# Name: 239, dtype: object
# 240 player_name                                        Javonte Green
# url            https://www.basketball-reference.com/players/g...
# Name: 240, dtype: object
# 243 player_name                                           Jeff Green
# url            https://www.basketball-reference.com/players/g...
# Name: 243, dtype: object
# 244 player_name                                           Josh Green
# url            https://www.basketball-reference.com/players/g...
# Name: 244, dtype: object
# 245 player_name                                        Blake Griffin
# url            https://www.basketball-reference.com/players/g...
# Name: 245, dtype: object
# 248 player_name                                             Kyle Guy
# url            https://www.basketball-reference.com/players/g...
# Name: 248, dtype: object
# 249 player_name                                        Rui Hachimura
# url            https://www.basketball-reference.com/players/h...
# Name: 249, dtype: object
# 250 player_name                                        Ashton Hagans
# url            https://www.basketball-reference.com/players/h...
# Name: 250, dtype: object
# 251 player_name                                    Tyrese Haliburton
# url            https://www.basketball-reference.com/players/h...
# Name: 251, dtype: object
# 252 player_name                                           Donta Hall
# url            https://www.basketball-reference.com/players/h...
# Name: 252, dtype: object
# 253 player_name                                            Josh Hall
# url            https://www.basketball-reference.com/players/h...
# Name: 253, dtype: object
# 254 player_name                                         R.J. Hampton
# url            https://www.basketball-reference.com/players/h...
# Name: 254, dtype: object
# 257 player_name                                     Tim Hardaway Jr.
# url            https://www.basketball-reference.com/players/h...
# Name: 257, dtype: object
# 258 player_name                                         James Harden
# url            https://www.basketball-reference.com/players/h...
# Name: 258, dtype: object
# 261 player_name                                     Maurice Harkless
# url            https://www.basketball-reference.com/players/h...
# Name: 261, dtype: object
# 264 player_name                                         Jared Harper
# url            https://www.basketball-reference.com/players/h...
# Name: 264, dtype: object
# 265 player_name                                     Montrezl Harrell
# url            https://www.basketball-reference.com/players/h...
# Name: 265, dtype: object
# 266 player_name                                          Gary Harris
# url            https://www.basketball-reference.com/players/h...
# Name: 266, dtype: object
# 269 player_name                                         Jalen Harris
# url            https://www.basketball-reference.com/players/h...
# Name: 269, dtype: object
# 270 player_name                                           Joe Harris
# url            https://www.basketball-reference.com/players/h...
# Name: 270, dtype: object
# 271 player_name                                        Tobias Harris
# url            https://www.basketball-reference.com/players/h...
# Name: 271, dtype: object
# 272 player_name                                   Shaquille Harrison
# url            https://www.basketball-reference.com/players/h...
# Name: 272, dtype: object
# 275 player_name                                            Josh Hart
# url            https://www.basketball-reference.com/players/h...
# Name: 275, dtype: object
# 276 player_name                                   Isaiah Hartenstein
# url            https://www.basketball-reference.com/players/h...
# Name: 276, dtype: object
# 279 player_name                                        Udonis Haslem
# url            https://www.basketball-reference.com/players/h...
# Name: 279, dtype: object
# 280 player_name                                         Jaxson Hayes
# url            https://www.basketball-reference.com/players/h...
# Name: 280, dtype: object
# 281 player_name                                        Killian Hayes
# url            https://www.basketball-reference.com/players/h...
# Name: 281, dtype: object
# 282 player_name                                       Gordon Hayward
# url            https://www.basketball-reference.com/players/h...
# Name: 282, dtype: object
# 283 player_name                                  Juancho Hernangómez
# url            https://www.basketball-reference.com/players/h...
# Name: 283, dtype: object
# 284 player_name                                    Willy Hernangómez
# url            https://www.basketball-reference.com/players/h...
# Name: 284, dtype: object
# 285 player_name                                          Tyler Herro
# url            https://www.basketball-reference.com/players/h...
# Name: 285, dtype: object
# 286 player_name                                          Buddy Hield
# url            https://www.basketball-reference.com/players/h...
# Name: 286, dtype: object
# 287 player_name                                          George Hill
# url            https://www.basketball-reference.com/players/h...
# Name: 287, dtype: object
# 290 player_name                                         Solomon Hill
# url            https://www.basketball-reference.com/players/h...
# Name: 290, dtype: object
# 291 player_name                                          Nate Hinton
# url            https://www.basketball-reference.com/players/h...
# Name: 291, dtype: object
# 292 player_name                                         Jaylen Hoard
# url            https://www.basketball-reference.com/players/h...
# Name: 292, dtype: object
# 293 player_name                                        Aaron Holiday
# url            https://www.basketball-reference.com/players/h...
# Name: 293, dtype: object
# 294 player_name                                         Jrue Holiday
# url            https://www.basketball-reference.com/players/h...
# Name: 294, dtype: object
# 295 player_name                                       Justin Holiday
# url            https://www.basketball-reference.com/players/h...
# Name: 295, dtype: object
# 296 player_name                              Rondae Hollis-Jefferson
# url            https://www.basketball-reference.com/players/h...
# Name: 296, dtype: object
# 297 player_name                                       Richaun Holmes
# url            https://www.basketball-reference.com/players/h...
# Name: 297, dtype: object
# 298 player_name                                          Rodney Hood
# url            https://www.basketball-reference.com/players/h...
# Name: 298, dtype: object
# 301 player_name                                           Al Horford
# url            https://www.basketball-reference.com/players/h...
# Name: 301, dtype: object
# 302 player_name                                  Talen Horton-Tucker
# url            https://www.basketball-reference.com/players/h...
# Name: 302, dtype: object
# 303 player_name                                     Danuel House Jr.
# url            https://www.basketball-reference.com/players/h...
# Name: 303, dtype: object
# 304 player_name                                        Dwight Howard
# url            https://www.basketball-reference.com/players/h...
# Name: 304, dtype: object
# 305 player_name                                        Markus Howard
# url            https://www.basketball-reference.com/players/h...
# Name: 305, dtype: object
# 306 player_name                                        Kevin Huerter
# url            https://www.basketball-reference.com/players/h...
# Name: 306, dtype: object
# 307 player_name                                        Elijah Hughes
# url            https://www.basketball-reference.com/players/h...
# Name: 307, dtype: object
# 308 player_name                                      De'Andre Hunter
# url            https://www.basketball-reference.com/players/h...
# Name: 308, dtype: object
# 309 player_name                                   Chandler Hutchison
# url            https://www.basketball-reference.com/players/h...
# Name: 309, dtype: object
# 312 player_name                                          Serge Ibaka
# url            https://www.basketball-reference.com/players/i...
# Name: 312, dtype: object
# 313 player_name                                       Andre Iguodala
# url            https://www.basketball-reference.com/players/i...
# Name: 313, dtype: object
# 314 player_name                                       Ersan İlyasova
# url            https://www.basketball-reference.com/players/i...
# Name: 314, dtype: object
# 315 player_name                                           Joe Ingles
# url            https://www.basketball-reference.com/players/i...
# Name: 315, dtype: object
# 316 player_name                                       Brandon Ingram
# url            https://www.basketball-reference.com/players/i...
# Name: 316, dtype: object
# 317 player_name                                         Kyrie Irving
# url            https://www.basketball-reference.com/players/i...
# Name: 317, dtype: object
# 318 player_name                                           Wes Iwundu
# url            https://www.basketball-reference.com/players/i...
# Name: 318, dtype: object
# 321 player_name                                        Frank Jackson
# url            https://www.basketball-reference.com/players/j...
# Name: 321, dtype: object
# 322 player_name                                    Jaren Jackson Jr.
# url            https://www.basketball-reference.com/players/j...
# Name: 322, dtype: object
# 323 player_name                                         Josh Jackson
# url            https://www.basketball-reference.com/players/j...
# Name: 323, dtype: object
# 324 player_name                                       Justin Jackson
# url            https://www.basketball-reference.com/players/j...
# Name: 324, dtype: object
# 327 player_name                                       Reggie Jackson
# url            https://www.basketball-reference.com/players/j...
# Name: 327, dtype: object
# 328 player_name                                         Justin James
# url            https://www.basketball-reference.com/players/j...
# Name: 328, dtype: object
# 329 player_name                                         LeBron James
# url            https://www.basketball-reference.com/players/j...
# Name: 329, dtype: object
# 330 player_name                                           Mike James
# url            https://www.basketball-reference.com/players/j...
# Name: 330, dtype: object
# 331 player_name                                      DaQuan Jeffries
# url            https://www.basketball-reference.com/players/j...
# Name: 331, dtype: object
# 334 player_name                                            Ty Jerome
# url            https://www.basketball-reference.com/players/j...
# Name: 334, dtype: object
# 335 player_name                                           Isaiah Joe
# url            https://www.basketball-reference.com/players/j...
# Name: 335, dtype: object
# 336 player_name                                        Alize Johnson
# url            https://www.basketball-reference.com/players/j...
# Name: 336, dtype: object
# 337 player_name                                      Cameron Johnson
# url            https://www.basketball-reference.com/players/j...
# Name: 337, dtype: object
# 338 player_name                                        James Johnson
# url            https://www.basketball-reference.com/players/j...
# Name: 338, dtype: object
# 341 player_name                                       Keldon Johnson
# url            https://www.basketball-reference.com/players/j...
# Name: 341, dtype: object
# 342 player_name                                      Stanley Johnson
# url            https://www.basketball-reference.com/players/j...
# Name: 342, dtype: object
# 343 player_name                                        Tyler Johnson
# url            https://www.basketball-reference.com/players/j...
# Name: 343, dtype: object
# 344 player_name                                         Nikola Jokić
# url            https://www.basketball-reference.com/players/j...
# Name: 344, dtype: object
# 345 player_name                                         Damian Jones
# url            https://www.basketball-reference.com/players/j...
# Name: 345, dtype: object
# 349 player_name                                    Derrick Jones Jr.
# url            https://www.basketball-reference.com/players/j...
# Name: 349, dtype: object
# 350 player_name                                          Mason Jones
# url            https://www.basketball-reference.com/players/j...
# Name: 350, dtype: object
# 353 player_name                                            Tre Jones
# url            https://www.basketball-reference.com/players/j...
# Name: 353, dtype: object
# 354 player_name                                           Tyus Jones
# url            https://www.basketball-reference.com/players/j...
# Name: 354, dtype: object
# 355 player_name                                       DeAndre Jordan
# url            https://www.basketball-reference.com/players/j...
# Name: 355, dtype: object
# 356 player_name                                          Cory Joseph
# url            https://www.basketball-reference.com/players/j...
# Name: 356, dtype: object
# 359 player_name                                    Mfiondu Kabengele
# url            https://www.basketball-reference.com/players/k...
# Name: 359, dtype: object
# 362 player_name                                       Frank Kaminsky
# url            https://www.basketball-reference.com/players/k...
# Name: 362, dtype: object
# 363 player_name                                         Luke Kennard
# url            https://www.basketball-reference.com/players/k...
# Name: 363, dtype: object
# 364 player_name                                           Louis King
# url            https://www.basketball-reference.com/players/k...
# Name: 364, dtype: object
# 365 player_name                                          Maxi Kleber
# url            https://www.basketball-reference.com/players/k...
# Name: 365, dtype: object
# 366 player_name                                        Nathan Knight
# url            https://www.basketball-reference.com/players/k...
# Name: 366, dtype: object
# 367 player_name                                           Kevin Knox
# url            https://www.basketball-reference.com/players/k...
# Name: 367, dtype: object
# 368 player_name                                         John Konchar
# url            https://www.basketball-reference.com/players/k...
# Name: 368, dtype: object
# 369 player_name                                       Furkan Korkmaz
# url            https://www.basketball-reference.com/players/k...
# Name: 369, dtype: object
# 370 player_name                                          Luke Kornet
# url            https://www.basketball-reference.com/players/k...
# Name: 370, dtype: object
# 373 player_name                                       Rodions Kurucs
# url            https://www.basketball-reference.com/players/k...
# Name: 373, dtype: object
# 377 player_name                                           Kyle Kuzma
# url            https://www.basketball-reference.com/players/k...
# Name: 377, dtype: object
# 378 player_name                                         Anthony Lamb
# url            https://www.basketball-reference.com/players/l...
# Name: 378, dtype: object
# 379 player_name                                          Jeremy Lamb
# url            https://www.basketball-reference.com/players/l...
# Name: 379, dtype: object
# 380 player_name                                       Romeo Langford
# url            https://www.basketball-reference.com/players/l...
# Name: 380, dtype: object
# 381 player_name                                          Zach LaVine
# url            https://www.basketball-reference.com/players/l...
# Name: 381, dtype: object
# 382 player_name                                          Jake Layman
# url            https://www.basketball-reference.com/players/l...
# Name: 382, dtype: object
# 383 player_name                                            T.J. Leaf
# url            https://www.basketball-reference.com/players/l...
# Name: 383, dtype: object
# 384 player_name                                         Jalen Lecque
# url            https://www.basketball-reference.com/players/l...
# Name: 384, dtype: object
# 385 player_name                                           Damion Lee
# url            https://www.basketball-reference.com/players/l...
# Name: 385, dtype: object
# 386 player_name                                            Saben Lee
# url            https://www.basketball-reference.com/players/l...
# Name: 386, dtype: object
# 387 player_name                                             Alex Len
# url            https://www.basketball-reference.com/players/l...
# Name: 387, dtype: object
# 390 player_name                                        Kawhi Leonard
# url            https://www.basketball-reference.com/players/l...
# Name: 390, dtype: object
# 391 player_name                                       Meyers Leonard
# url            https://www.basketball-reference.com/players/l...
# Name: 391, dtype: object
# 392 player_name                                         Caris LeVert
# url            https://www.basketball-reference.com/players/l...
# Name: 392, dtype: object
# 395 player_name                                       Kira Lewis Jr.
# url            https://www.basketball-reference.com/players/l...
# Name: 395, dtype: object
# 396 player_name                                       Damian Lillard
# url            https://www.basketball-reference.com/players/l...
# Name: 396, dtype: object
# 397 player_name                                        Nassir Little
# url            https://www.basketball-reference.com/players/l...
# Name: 397, dtype: object
# 398 player_name                                         Kevon Looney
# url            https://www.basketball-reference.com/players/l...
# Name: 398, dtype: object
# 399 player_name                                          Brook Lopez
# url            https://www.basketball-reference.com/players/l...
# Name: 399, dtype: object
# 400 player_name                                          Robin Lopez
# url            https://www.basketball-reference.com/players/l...
# Name: 400, dtype: object
# 401 player_name                                         Didi Louzada
# url            https://www.basketball-reference.com/players/l...
# Name: 401, dtype: object
# 402 player_name                                           Kevin Love
# url            https://www.basketball-reference.com/players/l...
# ...
# url            https://www.basketball-reference.com/players/r...
# Name: 573, dtype: object
# 574 player_name                                         Terry Rozier
# url            https://www.basketball-reference.com/players/r...
# Name: 574, dtype: object
# 575 player_name                                          Ricky Rubio
# url            https://www.basketball-reference.com/players/r...
# Name: 575, dtype: object
# 576 player_name                                     D'Angelo Russell
# url            https://www.basketball-reference.com/players/r...
# Name: 576, dtype: object
# 577 player_name                                     Domantas Sabonis
# url            https://www.basketball-reference.com/players/s...
# Name: 577, dtype: object
# 578 player_name                                         Luka Šamanić
# url            https://www.basketball-reference.com/players/s...
# Name: 578, dtype: object
# 579 player_name                                       JaKarr Sampson
# url            https://www.basketball-reference.com/players/s...
# Name: 579, dtype: object
# 580 player_name                                          Dario Šarić
# url            https://www.basketball-reference.com/players/s...
# Name: 580, dtype: object
# 581 player_name                                     Tomáš Satoranský
# url            https://www.basketball-reference.com/players/s...
# Name: 581, dtype: object
# 582 player_name                                      Dennis Schröder
# url            https://www.basketball-reference.com/players/s...
# Name: 582, dtype: object
# 583 player_name                                           Mike Scott
# url            https://www.basketball-reference.com/players/s...
# Name: 583, dtype: object
# 584 player_name                                           Jay Scrubb
# url            https://www.basketball-reference.com/players/s...
# Name: 584, dtype: object
# 585 player_name                                        Collin Sexton
# url            https://www.basketball-reference.com/players/s...
# Name: 585, dtype: object
# 586 player_name                                        Landry Shamet
# url            https://www.basketball-reference.com/players/s...
# Name: 586, dtype: object
# 587 player_name                                        Iman Shumpert
# url            https://www.basketball-reference.com/players/s...
# Name: 587, dtype: object
# 588 player_name                                        Pascal Siakam
# url            https://www.basketball-reference.com/players/s...
# Name: 588, dtype: object
# 589 player_name                                          Chris Silva
# url            https://www.basketball-reference.com/players/s...
# Name: 589, dtype: object
# 592 player_name                                          Ben Simmons
# url            https://www.basketball-reference.com/players/s...
# Name: 592, dtype: object
# 593 player_name                                      Anfernee Simons
# url            https://www.basketball-reference.com/players/s...
# Name: 593, dtype: object
# 594 player_name                                    Deividas Sirvydis
# url            https://www.basketball-reference.com/players/s...
# Name: 594, dtype: object
# 595 player_name                                       Alen Smailagić
# url            https://www.basketball-reference.com/players/s...
# Name: 595, dtype: object
# 596 player_name                                         Marcus Smart
# url            https://www.basketball-reference.com/players/s...
# Name: 596, dtype: object
# 597 player_name                                     Dennis Smith Jr.
# url            https://www.basketball-reference.com/players/s...
# Name: 597, dtype: object
# 600 player_name                                            Ish Smith
# url            https://www.basketball-reference.com/players/s...
# Name: 600, dtype: object
# 601 player_name                                          Jalen Smith
# url            https://www.basketball-reference.com/players/s...
# Name: 601, dtype: object
# 602 player_name                                           Tony Snell
# url            https://www.basketball-reference.com/players/s...
# Name: 602, dtype: object
# 603 player_name                                         Ray Spalding
# url            https://www.basketball-reference.com/players/s...
# Name: 603, dtype: object
# 604 player_name                                      Cassius Stanley
# url            https://www.basketball-reference.com/players/s...
# Name: 604, dtype: object
# 605 player_name                                        Lamar Stevens
# url            https://www.basketball-reference.com/players/s...
# Name: 605, dtype: object
# 606 player_name                                       Isaiah Stewart
# url            https://www.basketball-reference.com/players/s...
# Name: 606, dtype: object
# 607 player_name                                            Max Strus
# url            https://www.basketball-reference.com/players/s...
# Name: 607, dtype: object
# 608 player_name                                        Edmond Sumner
# url            https://www.basketball-reference.com/players/s...
# Name: 608, dtype: object
# 609 player_name                                        Jae'Sean Tate
# url            https://www.basketball-reference.com/players/t...
# Name: 609, dtype: object
# 610 player_name                                         Jayson Tatum
# url            https://www.basketball-reference.com/players/t...
# Name: 610, dtype: object
# 611 player_name                                          Jeff Teague
# url            https://www.basketball-reference.com/players/t...
# Name: 611, dtype: object
# 614 player_name                                       Garrett Temple
# url            https://www.basketball-reference.com/players/t...
# Name: 614, dtype: object
# 615 player_name                                         Tyrell Terry
# url            https://www.basketball-reference.com/players/t...
# Name: 615, dtype: object
# 616 player_name                                         Daniel Theis
# url            https://www.basketball-reference.com/players/t...
# Name: 616, dtype: object
# 619 player_name                                       Brodric Thomas
# url            https://www.basketball-reference.com/players/t...
# Name: 619, dtype: object
# 622 player_name                                        Isaiah Thomas
# url            https://www.basketball-reference.com/players/t...
# Name: 622, dtype: object
# 623 player_name                                         Khyri Thomas
# url            https://www.basketball-reference.com/players/t...
# Name: 623, dtype: object
# 624 player_name                                          Matt Thomas
# url            https://www.basketball-reference.com/players/t...
# Name: 624, dtype: object
# 627 player_name                                     Tristan Thompson
# url            https://www.basketball-reference.com/players/t...
# Name: 627, dtype: object
# 628 player_name                                  Sindarius Thornwell
# url            https://www.basketball-reference.com/players/t...
# Name: 628, dtype: object
# 631 player_name                                     Matisse Thybulle
# url            https://www.basketball-reference.com/players/t...
# Name: 631, dtype: object
# 632 player_name                                       Killian Tillie
# url            https://www.basketball-reference.com/players/t...
# Name: 632, dtype: object
# 633 player_name                                   Xavier Tillman Sr.
# url            https://www.basketball-reference.com/players/t...
# Name: 633, dtype: object
# 634 player_name                                     Anthony Tolliver
# url            https://www.basketball-reference.com/players/t...
# Name: 634, dtype: object
# 635 player_name                                           Obi Toppin
# url            https://www.basketball-reference.com/players/t...
# Name: 635, dtype: object
# 636 player_name                                Juan Toscano-Anderson
# url            https://www.basketball-reference.com/players/t...
# Name: 636, dtype: object
# 637 player_name                                         Axel Toupane
# url            https://www.basketball-reference.com/players/t...
# Name: 637, dtype: object
# 638 player_name                                   Karl-Anthony Towns
# url            https://www.basketball-reference.com/players/t...
# Name: 638, dtype: object
# 639 player_name                                       Gary Trent Jr.
# url            https://www.basketball-reference.com/players/t...
# Name: 639, dtype: object
# 642 player_name                                          P.J. Tucker
# url            https://www.basketball-reference.com/players/t...
# Name: 642, dtype: object
# 645 player_name                                        Rayjon Tucker
# url            https://www.basketball-reference.com/players/t...
# Name: 645, dtype: object
# 646 player_name                                         Myles Turner
# url            https://www.basketball-reference.com/players/t...
# Name: 646, dtype: object
# 647 player_name                                    Jonas Valančiūnas
# url            https://www.basketball-reference.com/players/v...
# Name: 647, dtype: object
# 648 player_name                                     Denzel Valentine
# url            https://www.basketball-reference.com/players/v...
# Name: 648, dtype: object
# 649 player_name                                    Jarred Vanderbilt
# url            https://www.basketball-reference.com/players/v...
# Name: 649, dtype: object
# 650 player_name                                        Fred VanVleet
# url            https://www.basketball-reference.com/players/v...
# Name: 650, dtype: object
# 651 player_name                                     Anderson Varejão
# url            https://www.basketball-reference.com/players/v...
# Name: 651, dtype: object
# 652 player_name                                        Devin Vassell
# url            https://www.basketball-reference.com/players/v...
# Name: 652, dtype: object
# 653 player_name                                         Gabe Vincent
# url            https://www.basketball-reference.com/players/v...
# Name: 653, dtype: object
# 654 player_name                                          Noah Vonleh
# url            https://www.basketball-reference.com/players/v...
# Name: 654, dtype: object
# 655 player_name                                       Nikola Vučević
# url            https://www.basketball-reference.com/players/v...
# Name: 655, dtype: object
# 658 player_name                                            Dean Wade
# url            https://www.basketball-reference.com/players/w...
# Name: 658, dtype: object
# 659 player_name                                        Moritz Wagner
# url            https://www.basketball-reference.com/players/w...
# Name: 659, dtype: object
# 663 player_name                                         Kemba Walker
# url            https://www.basketball-reference.com/players/w...
# Name: 663, dtype: object
# 664 player_name                                     Lonnie Walker IV
# url            https://www.basketball-reference.com/players/w...
# Name: 664, dtype: object
# 665 player_name                                            John Wall
# url            https://www.basketball-reference.com/players/w...
# Name: 665, dtype: object
# 666 player_name                                       Brad Wanamaker
# url            https://www.basketball-reference.com/players/w...
# Name: 666, dtype: object
# 669 player_name                                          T.J. Warren
# url            https://www.basketball-reference.com/players/w...
# Name: 669, dtype: object
# 670 player_name                                      P.J. Washington
# url            https://www.basketball-reference.com/players/w...
# Name: 670, dtype: object
# 671 player_name                                        Yuta Watanabe
# url            https://www.basketball-reference.com/players/w...
# Name: 671, dtype: object
# 672 player_name                                       Tremont Waters
# url            https://www.basketball-reference.com/players/w...
# Name: 672, dtype: object
# 673 player_name                                          Paul Watson
# url            https://www.basketball-reference.com/players/w...
# Name: 673, dtype: object
# 674 player_name                               Quinndary Weatherspoon
# url            https://www.basketball-reference.com/players/w...
# Name: 674, dtype: object
# 675 player_name                                    Russell Westbrook
# url            https://www.basketball-reference.com/players/w...
# Name: 675, dtype: object
# 676 player_name                                           Coby White
# url            https://www.basketball-reference.com/players/w...
# Name: 676, dtype: object
# 677 player_name                                        Derrick White
# url            https://www.basketball-reference.com/players/w...
# Name: 677, dtype: object
# 678 player_name                                     Hassan Whiteside
# url            https://www.basketball-reference.com/players/w...
# Name: 678, dtype: object
# 679 player_name                                     Greg Whittington
# url            https://www.basketball-reference.com/players/w...
# Name: 679, dtype: object
# 680 player_name                                       Andrew Wiggins
# url            https://www.basketball-reference.com/players/w...
# Name: 680, dtype: object
# 681 player_name                                       Grant Williams
# url            https://www.basketball-reference.com/players/w...
# Name: 681, dtype: object
# 682 player_name                                     Kenrich Williams
# url            https://www.basketball-reference.com/players/w...
# Name: 682, dtype: object
# 683 player_name                                         Lou Williams
# url            https://www.basketball-reference.com/players/w...
# Name: 683, dtype: object
# 686 player_name                                     Patrick Williams
# url            https://www.basketball-reference.com/players/w...
# Name: 686, dtype: object
# 687 player_name                                      Robert Williams
# url            https://www.basketball-reference.com/players/w...
# Name: 687, dtype: object
# 688 player_name                                      Zion Williamson
# url            https://www.basketball-reference.com/players/w...
# Name: 688, dtype: object
# 689 player_name                                          D.J. Wilson
# url            https://www.basketball-reference.com/players/w...
# Name: 689, dtype: object
# 692 player_name                                        Dylan Windler
# url            https://www.basketball-reference.com/players/w...
# Name: 692, dtype: object
# 693 player_name                                      Justise Winslow
# url            https://www.basketball-reference.com/players/w...
# Name: 693, dtype: object
# 694 player_name                                      Cassius Winston
# url            https://www.basketball-reference.com/players/w...
# Name: 694, dtype: object
# 695 player_name                                        James Wiseman
# url            https://www.basketball-reference.com/players/w...
# Name: 695, dtype: object
# 696 player_name                                       Christian Wood
# url            https://www.basketball-reference.com/players/w...
# Name: 696, dtype: object
# 697 player_name                                    Robert Woodard II
# url            https://www.basketball-reference.com/players/w...
# Name: 697, dtype: object
# 698 player_name                                         Delon Wright
# url            https://www.basketball-reference.com/players/w...
# Name: 698, dtype: object
# 701 player_name                                       Thaddeus Young
# url            https://www.basketball-reference.com/players/y...
# Name: 701, dtype: object
# 702 player_name                                           Trae Young
# url            https://www.basketball-reference.com/players/y...
# Name: 702, dtype: object
# 703 player_name                                          Cody Zeller
# url            https://www.basketball-reference.com/players/z...
# Name: 703, dtype: object
# 704 player_name                                          Ivica Zubac
# url            https://www.basketball-reference.com/players/z...
# Name: 704, dtype: object

# %%
html_stat = get_nba_collegestat('https://www.basketball-reference.com/players/a/achiupr01.html')
pl = extract_nba_collegestat(html_stat)
pl
# Out:
# {'season': ['2019-20'],
#  'age': ['20'],
#  'college_id': ['MEMPHIS'],
#  'g': ['31'],
#  'mp': ['943'],
#  'fg': ['182'],
#  'fga': ['369'],
#  'fg3': ['13'],
#  'fg3a': ['40'],
#  'ft': ['112'],
#  'fta': ['187'],
#  'orb': ['93'],
#  'trb': ['334'],
#  'ast': ['30'],
#  'stl': ['34'],
#  'blk': ['58'],
#  'tov': ['87'],
#  'pf': ['73'],
#  'pts': ['489'],
#  'fg_pct': ['.493'],
#  'fg3_pct': ['.325'],
#  'ft_pct': ['.599'],
#  'mp_per_g': ['30.4'],
#  'pts_per_g': ['15.8'],
#  'trb_per_g': ['10.8'],
#  'ast_per_g': ['1.0']}

# %%
build_nba_college(df_player.head())
# Out:
# https://www.basketball-reference.com/players/a/achiupr01.html
# https://www.basketball-reference.com/players/a/adamsja01.html
# https://www.basketball-reference.com/players/a/adamsst01.html
# https://www.basketball-reference.com/players/a/adebaba01.html
# https://www.basketball-reference.com/players/a/aldrila01.html
#     season age college_id   g    mp   fg  fga fg3 fg3a   ft  ...  pf  pts  \
# 0  2019-20  20    MEMPHIS  31   943  182  369  13   40  112  ...  73  489
# 0  2014-15  18    STBONNY  22   714   61  158  34  105   65  ...  47  221
# 1  2015-16  19    STBONNY  30  1125  150  337  84  192  153  ...  80  537
# 2  2016-17  20    STBONNY  30  1123  168  401  77  216  206  ...  84  619
# 3  2017-18  21    STBONNY  28  1036  153  350  75  172  154  ...  80  535
# 0  2012-13  19       PITT  32   749  100  175   0    0   31  ...  52  231
# 0  2016-17  19   KENTUCKY  38  1145  170  284   0    0  154  ...  99  494
# 0  2004-05  19      TEXAS  16   355   57   86   0    0   44  ...      158
# 1  2005-06  20      TEXAS  37  1247  219  385   0    0  117  ...      555
#
#   fg_pct fg3_pct ft_pct mp_per_g pts_per_g trb_per_g ast_per_g  \
# 0   .493    .325   .599     30.4      15.8      10.8       1.0
# 0   .386    .324   .783     32.5      10.0       2.5       4.5
# 1   .445    .438   .874     37.5      17.9       3.7       5.0
# 2   .419    .356   .821     37.4      20.6       3.7       6.5
# 3   .437    .436   .851     37.0      19.1       3.4       5.2
# 0   .571           .443     23.4       7.2       6.3       0.6
# 0   .599           .653     30.1      13.0       8.0       0.8
# 0   .663           .657     22.2       9.9       5.9       0.9
# 1   .569           .646     33.7      15.0       9.2       0.5
#
#          player_name
# 0   Precious Achiuwa
# 0       Jaylen Adams
# 1       Jaylen Adams
# 2       Jaylen Adams
# 3       Jaylen Adams
# 0       Steven Adams
# 0        Bam Adebayo
# 0  LaMarcus Aldridge
# 1  LaMarcus Aldridge
#
# [9 rows x 27 columns]
